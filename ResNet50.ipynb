# %% [markdown]
# # Using ResNet50 to analyse images
#
# ResNet50 is a neural network trained using ImageNet.
#
# ## Required imports

# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions

import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Loading the pretrained network ResNet50

# %%
model = ResNet50(weights='imagenet')

# %% [markdown]
# ## Loading, preprocessing and showing the image
#
# Replace 'my_image.jpg' by the filename of the picture you want to analyse.

# %%
img_path = 'my_image.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
plt.imshow(img)

# %%
preds = model.predict(x)
print('Predicted:')
for i in range(3):
    print(decode_predictions(preds, top=3)[0][i][1:])
# Out:
# Predicted:
# ('terrapin', 0.85205263)
# ('box_turtle', 0.079021849)
# ('mud_turtle', 0.064380832)
